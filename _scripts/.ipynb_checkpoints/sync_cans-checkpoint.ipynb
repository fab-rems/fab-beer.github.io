# %%
# %cd /Users/ben/prj/fab/_scripts

# %%
## FROM SYNC_CANS.PY
#!/usr/bin/env python

import fill_untappd
import yaml, json, sqlite3,  dateparser,os, sys
from pprint import pprint
from airtable import Airtable
import pandas as pd


def main():
    fill_untappd.run()
    conn = sqlite3.connect("untappd.db")
    df = pd.read_sql_query("select * from checkins;", conn)
    jsons  = df.json.apply(lambda j: json.loads(j))

    venues = jsons.apply(
        lambda x: 
        pd.concat([
            pd.Series(x["venue"]),
            pd.Series(x["user"])[["user_name"]],
            pd.Series(x["beer"]),
            pd.Series(x)[["checkin_id","created_at","rating_score"]]
            ])
            )

    venues_info = pd.concat([venues, 
    pd.concat([
        venues['contact'].apply(lambda x: pd.Series(x)),
        venues['location'].apply(lambda x: pd.Series(x)),
    ], axis = 1)],axis=1).set_index(["venue_slug","beer_slug"])

    venue_users = venues_info.groupby(["venue_slug","beer_slug"]).user_name.apply(','.join).rename("user_names")
    venue_rating = venues_info.groupby(["venue_slug","beer_slug"]).rating_score.sum().rename("total_rating")
    venue_counts = venues_info.groupby(["venue_slug","beer_slug"]).size().rename("n_checkins").astype(int)
    venue_last_checkin = venues_info.groupby(["venue_slug","beer_slug"]).created_at.apply(lambda x: x.apply(lambda y:dateparser.parse(y)).max()).rename("last_checkin")


    venues_info_dedup = venues_info.loc[~venues_info.index.duplicated()]
    venues_annotated = venues_info_dedup.join(pd.concat([venue_users, venue_rating, venue_counts,venue_last_checkin],axis=1))

    venues_annotated = venues_annotated.loc[ lambda x: x.venue_url != ""]
    venues_annotated = venues_annotated.loc[ venues_annotated.venue_url.notna()]
    venues_annotated = venues_annotated.loc[ lambda x: x.venue_city != ""]
    venues_annotated = venues_annotated.loc[ venues_annotated.venue_city.notna()]


    cans = pd.read_csv("../_data/cans.csv")
    cans["untappd_id"] = cans.untappd.str.extract('(\d*$)').astype(int)

    venue_beers_annotated = venues_annotated.loc[lambda x: x.venue_id.notna()]
    venue_beers_annotated = venue_beers_annotated.join(cans.set_index("untappd_id")[["code"]], on ="bid")
    venue_beers_annotated = venue_beers_annotated.rename({"code":"can_code"}, axis = "columns")
    venue_beers_annotated["venue_id"] = venue_beers_annotated["venue_id"].astype(int)
    venue_beers_annotated.n_checkins = venue_beers_annotated.n_checkins.astype(int)

    venue_beers_annotated.to_csv("../_data/venue_beers.csv")

    venues_annotated = venue_beers_annotated.reset_index()[["venue_name","venue_slug","primary_category","contact","venue_id","lat","lng","venue_city" , "venue_address","venue_country","venue_city",	"venue_country",	"venue_state",'venue_url']]
    venues_annotated.to_csv("../_data/venues.csv")

# if __name__ == "__main__":
#     os.chdir(os.path.abspath(os.path.dirname(sys.argv[0])))
#     main()

# %%
main()
# Out:
# {'client_id': 'E8847D1FA347C37248DEC90E1D21568E18FC5152', 'client_secret': '199C86117D183A9B6BCB3220098F34CFF81FD562', 'limit': 100, 'min_id': 871192668}
# {'count': 25, 'items': [{'checkin_id': 871703610, 'created_at': 'Fri, 28 Feb 2020 02:40:30 +0000', 'checkin_comment': 'Surprisingly crushable for a 9% dIPA. Definitely worth checking out if you’re a fan of a very fruit forward east coast IPA.', 'rating_score': 4.25, 'user': {'uid': 7526907, 'user_name': 'chappyy', 'first_name': 'Chappy', 'last_name': 'W.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/3414841aa1a61232b187abe4605121d8-fb_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': [], 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871703610, 'comment_id': 55960992, 'comment_owner': False, 'comment_editor': False, 'comment': '🐙🍊🍽️', 'created_at': 'Fri, 28 Feb 2020 04:10:35 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595411, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:10:22 +0000'}]}, 'media': {'count': 1, 'items': [{'photo_id': 281751764, 'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_200x200.jpg', 'photo_img_md': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_640x640.jpg', 'photo_img_lg': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_1280x1280.jpg', 'photo_img_og': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_raw.jpg'}}]}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges' ...
# {'checkin_id': 871703610, 'created_at': 'Fri, 28 Feb 2020 02:40:30 +0000', 'checkin_comment': 'Surprisingly crushable for a 9% dIPA. Definitely worth checking out if you’re a fan of a very fruit forward east coast IPA.', 'rating_score': 4.25, 'user': {'uid': 7526907, 'user_name': 'chappyy', 'first_name': 'Chappy', 'last_name': 'W.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/3414841aa1a61232b187abe4605121d8-fb_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': [], 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871703610, 'comment_id': 55960992, 'comment_owner': False, 'comment_editor': False, 'comment': '🐙🍊🍽️', 'created_at': 'Fri, 28 Feb 2020 04:10:35 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595411, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:10:22 +0000'}]}, 'media': {'count': 1, 'items': [{'photo_id': 281751764, 'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_200x200.jpg', 'photo_img_md': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_640x640.jpg', 'photo_img_lg': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_1280x1280.jpg', 'photo_img_og': 'https://untappd.akamaized.net/photos/2020_02_28/25792e76a7447d7c49be852aa9c6bf42_raw.jpg'}}]}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges': {'retro_status': False ...
# 871703610 2020-02-27 21:40:30-05:00 b'Tremendous  "TREM"' b''
# {'checkin_id': 871693074, 'created_at': 'Fri, 28 Feb 2020 02:14:25 +0000', 'checkin_comment': 'Delightful!!! Would fucks with this beer on the regs.', 'rating_score': 4.5, 'user': {'uid': 4350100, 'user_name': 'squidles', 'first_name': 'Sydney', 'last_name': 'R.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/c6766b7e15675d76fa7a5551b83815f9_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3568228, 'beer_name': 'Squid Pro Quo "SPQ"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3568228_6faf9_sm.jpeg', 'beer_abv': 8, 'beer_ibu': 40, 'beer_slug': 'fab-fermentation-arts-fabcans-squid-pro-quo-spq', 'beer_description': 'fab.beer/spq; Chico fermented. West coast style.\r\n\r\nFermented with classic California ale yeast, SQP has a smoothly integrated citrus hop flavor happiness coming from a substantial bill of Citra and Simcoe hops added early in the mash and in multiple rounds of dry hopping. Naturally carbonated, Squid Pro Quo is capped after the last round of dry hopping to capture maximum hop aroma and create a fine, champagne-like carbonation', 'beer_style': 'IPA - American', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 184821, 'venue_name': 'PUBLIC eat+drink', 'venue_slug': 'public-eat-drink', 'primary_category_key': 'Food', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'new_american_restaurant', 'category_name': 'New American Restaurant', 'category_id': '4bf58dd8d48988d157941735', 'is_primary': True}]}, 'location': {'venue_address': '34 Holden St', 'venue_city': 'North Adams', 'venue_state': 'MA', 'venue_country': 'United States', 'lat': 42.7002, 'lng': -73.1118}, 'contact': {'twitter': '@publicna', 'venue_url': 'http://www.publiceatanddrink.com'}, 'foursquare': {'foursquare_id': '4e246586a80968cf3e5ce68b', 'foursquare_url': 'http://4sq.com/qudn1j'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871693074, 'comment_id': 55960986, 'comment_owner': False, 'comment_editor': False, 'comment': 'Rad! You should check out Citra squid, coming soon! 🍊🐙 ( fab.beer/sticky for updates)', 'created_at': 'Fri, 28 Feb 2020 04:10:14 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 2, 'count': 2, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595164, 'like_owner': False, 'created_at': ' ...
# 871693074 2020-02-27 21:14:25-05:00 b'Squid Pro Quo "SPQ"' b'PUBLIC eat+drink'
# {'checkin_id': 871684095, 'created_at': 'Fri, 28 Feb 2020 01:54:02 +0000', 'checkin_comment': '', 'rating_score': 4, 'user': {'uid': 6110694, 'user_name': 'drewfack', 'first_name': 'Drew', 'last_name': 'F.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/81ca1e6e55087ac32ac29e8b3d012191_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 2362, 'venue_name': 'Bukowski Tavern- Boston', 'venue_slug': 'bukowski-tavern', 'primary_category_key': 'Nightlife Spot', 'primary_category': 'Nightlife Spot', 'parent_category_id': '4d4b7105d754a06376d81259', 'categories': {'count': 2, 'items': [{'category_key': 'bar', 'category_name': 'Bar', 'category_id': '4bf58dd8d48988d116941735', 'is_primary': True}, {'category_key': 'beer_bar', 'category_name': 'Beer Bar', 'category_id': '56aa371ce4b08b9a8d57356c', 'is_primary': False}]}, 'location': {'venue_address': '50 Dalton St', 'venue_city': 'Boston', 'venue_state': 'MA', 'venue_country': 'United States', 'lat': 42.3472, 'lng': -71.0854}, 'contact': {'twitter': '@bukowskiboston', 'venue_url': 'http://bukowskitavern.net/'}, 'foursquare': {'foursquare_id': '40b28c80f964a520f2f71ee3', 'foursquare_url': 'http://4sq.com/18dxEv'}, 'venue_icon': {'sm': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_64.png', 'md': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_88.png', 'lg': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_176.png?v=1'}, 'is_verified': True}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871684095, 'comment_id': 55960975, 'comment_owner': False, 'comment_editor': False, 'comment': 'Coming to Buks for super Tuesday! 🐙🛸🌍', 'created_at': 'Fri, 28 Feb 2020 04:09:23 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'F ...
# 871684095 2020-02-27 20:54:02-05:00 b'Tremendous  "TREM"' b'Bukowski Tavern- Boston'
# {'checkin_id': 871683220, 'created_at': 'Fri, 28 Feb 2020 01:51:59 +0000', 'checkin_comment': '', 'rating_score': 3, 'user': {'uid': 7118951, 'user_name': 'Kdimuzio', 'first_name': 'Katy', 'last_name': 'D.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/6f5445594686182f8b5e2e22e7d30732-fb_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 2362, 'venue_name': 'Bukowski Tavern- Boston', 'venue_slug': 'bukowski-tavern', 'primary_category_key': 'Nightlife Spot', 'primary_category': 'Nightlife Spot', 'parent_category_id': '4d4b7105d754a06376d81259', 'categories': {'count': 2, 'items': [{'category_key': 'bar', 'category_name': 'Bar', 'category_id': '4bf58dd8d48988d116941735', 'is_primary': True}, {'category_key': 'beer_bar', 'category_name': 'Beer Bar', 'category_id': '56aa371ce4b08b9a8d57356c', 'is_primary': False}]}, 'location': {'venue_address': '50 Dalton St', 'venue_city': 'Boston', 'venue_state': 'MA', 'venue_country': 'United States', 'lat': 42.3472, 'lng': -71.0854}, 'contact': {'twitter': '@bukowskiboston', 'venue_url': 'http://bukowskitavern.net/'}, 'foursquare': {'foursquare_id': '40b28c80f964a520f2f71ee3', 'foursquare_url': 'http://4sq.com/18dxEv'}, 'venue_icon': {'sm': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_64.png', 'md': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_88.png', 'lg': 'https://untappd.akamaized.net/site/assets/images/temp/verfied-venue_bg_176.png?v=1'}, 'is_verified': True}, 'comments': {'total_count': 0, 'count': 0, 'items': []}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595070, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:09:04 +0000'}]}, 'media': {'count': 0, 'items': []}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges': {'retro_status': False, 'count': 2, 'items': [{'badge_id': 243500,  ...
# 871683220 2020-02-27 20:51:59-05:00 b'Tremendous  "TREM"' b'Bukowski Tavern- Boston'
# {'checkin_id': 871656151, 'created_at': 'Fri, 28 Feb 2020 00:54:33 +0000', 'checkin_comment': '', 'rating_score': 3.75, 'user': {'uid': 2853503, 'user_name': 'OBriBoost', 'first_name': 'Thomas', 'last_name': 'O.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/8e7cbcf8aefa574946fca9192f568922_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': [], 'comments': {'total_count': 0, 'count': 0, 'items': []}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595035, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:08:56 +0000'}]}, 'media': {'count': 1, 'items': [{'photo_id': 281734026, 'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2020_02_28/7228ea737925e0dbadd186d141e63632_200x200.jpg', 'photo_img_md': 'https://untappd.akamaized.net/photos/2020_02_28/7228ea737925e0dbadd186d141e63632_640x640.jpg', 'photo_img_lg': 'https://untappd.akamaized.net/photos/2020_02_28/7228ea737925e0dbadd186d141e63632_1280x1280.jpg', 'photo_img_og': 'https://untappd.akamaized.net/photos/2020_02_28/7228ea737925e0dbadd186d141e63632_raw.jpg'}}]}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges': {'retro_status': False, 'count': 2, 'items': [{'badge_id': 133360, 'user_badge_id': 640249063, 'badge_name': 'For the Can (Level 7)', 'badge_description': "Canning is all the rage and it's not hard to see why - travels well, more environmentally friendly, and no need to carry your bottle opener. That's 35 checkins with the serving style of Can. Try 5 more for Level 8!", 'created_at': 'Fri, 28 Feb 2020 00:54:33 +0000', 'badge_image': {'sm': 'https://untappd.akamaized.net/badges/bdg_GloryCan_sm.jpg', 'md': 'https://untappd.akamaized.net/badges/bdg_GloryCan_md.jpg', 'lg': 'https://untappd.akamaized.net/badges/bdg_GloryCan_lg.jpg'}}, {'badge_id': 2600, 'user_badge_id': 640249064, 'badge_name': 'I Believe in IPA!  (Level 14)' ...
# 871656151 2020-02-27 19:54:33-05:00 b'Tremendous  "TREM"' b''
# {'checkin_id': 871639203, 'created_at': 'Fri, 28 Feb 2020 00:20:24 +0000', 'checkin_comment': '', 'rating_score': 3.75, 'user': {'uid': 4296742, 'user_name': 'lam1611', 'first_name': 'Leigh', 'last_name': 'M.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/57ac87b7c61bb19f62c8fbbcad23413c_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 4259094, 'venue_name': 'The Slow Rhode', 'venue_slug': 'the-slow-rhode', 'primary_category_key': 'Food', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'new_american_restaurant', 'category_name': 'New American Restaurant', 'category_id': '4bf58dd8d48988d157941735', 'is_primary': True}]}, 'location': {'venue_address': '425 W Fountain St', 'venue_city': 'Providence', 'venue_state': 'RI', 'venue_country': 'United States', 'lat': 41.819, 'lng': -71.4239}, 'contact': {'twitter': '', 'venue_url': ''}, 'foursquare': {'foursquare_id': '56a18d76498ed994a6433c28', 'foursquare_url': 'http://4sq.com/1nBNgQm'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 0, 'count': 0, 'items': []}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787595029, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:08:55 +0000'}]}, 'media': {'count': 0, 'items': []}, 'source': {'app_name': 'Untappd for Android - (V2)', 'app_website': 'http://untpd.it/androidapp'}, 'badges': {'count': 0, 'items': []}}
# 871639203 2020-02-27 19:20:24-05:00 b'Tremendous  "TREM"' b'The Slow Rhode'
# {'checkin_id': 871637846, 'created_at': 'Fri, 28 Feb 2020 00:17:43 +0000', 'checkin_comment': 'Really good!', 'rating_score': 4.25, 'user': {'uid': 3535328, 'user_name': 'jrexcubitor', 'first_name': 'Jason', 'last_name': 'R.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/7195136888361d1fd08a2cdc8a248ce1_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 6956019, 'venue_name': 'Craft Brew Underground', 'venue_slug': 'craft-brew-underground', 'primary_category_key': 'Nightlife Spot', 'primary_category': 'Nightlife Spot', 'parent_category_id': '4d4b7105d754a06376d81259', 'categories': {'count': 1, 'items': [{'category_key': 'bar', 'category_name': 'Bar', 'category_id': '4bf58dd8d48988d116941735', 'is_primary': True}]}, 'location': {'venue_address': '34 Court St, Basement', 'venue_city': 'Auburn', 'venue_state': 'ME', 'venue_country': 'United States', 'lat': 44.0972, 'lng': -70.2251}, 'contact': {'twitter': '', 'venue_url': 'https://www.facebook.com/CBUAuburn/'}, 'foursquare': {'foursquare_id': '59f8bf24135b3976110a386d', 'foursquare_url': 'http://4sq.com/2ikE6Xp'}, 'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_6956019_06a93387_bg_64.png', 'md': 'https://untappd.akamaized.net/venuelogos/venue_6956019_06a93387_bg_88.png', 'lg': 'https://untappd.akamaized.net/venuelogos/venue_6956019_06a93387_bg_176.png?v=1'}, 'is_verified': True}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871637846, 'comment_id': 55960969, 'comment_owner': False, 'comment_editor': False, 'comment': 'You too! 🐙✋', 'created_at': 'Fri, 28 Feb 2020 04:08:52 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewe ...
# 871637846 2020-02-27 19:17:43-05:00 b'Tremendous  "TREM"' b'Craft Brew Underground'
# {'checkin_id': 871637420, 'created_at': 'Fri, 28 Feb 2020 00:16:53 +0000', 'checkin_comment': '', 'rating_score': 4.25, 'user': {'uid': 2326480, 'user_name': 'amaz1007', 'first_name': 'Andres', 'last_name': 'M.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/b483d1e5c4d63d244a9b443bb5669ade_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 4259094, 'venue_name': 'The Slow Rhode', 'venue_slug': 'the-slow-rhode', 'primary_category_key': 'Food', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'new_american_restaurant', 'category_name': 'New American Restaurant', 'category_id': '4bf58dd8d48988d157941735', 'is_primary': True}]}, 'location': {'venue_address': '425 W Fountain St', 'venue_city': 'Providence', 'venue_state': 'RI', 'venue_country': 'United States', 'lat': 41.819, 'lng': -71.4239}, 'contact': {'twitter': '', 'venue_url': ''}, 'foursquare': {'foursquare_id': '56a18d76498ed994a6433c28', 'foursquare_url': 'http://4sq.com/1nBNgQm'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871637420, 'comment_id': 55960964, 'comment_owner': False, 'comment_editor': False, 'comment': '🐙🛸🛸', 'created_at': 'Fri, 28 Feb 2020 04:08:44 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details':  ...
# 871637420 2020-02-27 19:16:53-05:00 b'Tremendous  "TREM"' b'The Slow Rhode'
# {'checkin_id': 871633910, 'created_at': 'Fri, 28 Feb 2020 00:09:51 +0000', 'checkin_comment': '', 'rating_score': 4.25, 'user': {'uid': 3866081, 'user_name': 'Jhole', 'first_name': 'J', 'last_name': '', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/1a27ec13b333090c66e627014c22ebae_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 2396148, 'venue_name': 'Groveland police', 'venue_slug': 'groveland-police', 'primary_category_key': 'Professional & Other Places', 'primary_category': 'Professional & Other Places', 'parent_category_id': '4d4b7105d754a06375d81259', 'categories': {'count': 1, 'items': [{'category_key': 'police_station', 'category_name': 'Police Station', 'category_id': '4bf58dd8d48988d12e941735', 'is_primary': True}]}, 'location': {'venue_address': '', 'venue_city': 'Groveland', 'venue_state': 'MA', 'venue_country': 'United States', 'lat': 42.7632, 'lng': -71.024}, 'contact': {'twitter': '', 'venue_url': ''}, 'foursquare': {'foursquare_id': '4fba8e76e4b07e915b643e23', 'foursquare_url': 'http://4sq.com/K4R2J5'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871633910, 'comment_id': 55960961, 'comment_owner': False, 'comment_editor': False, 'comment': '🐙🛸', 'created_at': 'Fri, 28 Feb 2020 04:08:37 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 2, 'count': 2, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d ...
# 871633910 2020-02-27 19:09:51-05:00 b'Tremendous  "TREM"' b'Groveland police'
# {'checkin_id': 871618058, 'created_at': 'Thu, 27 Feb 2020 23:36:22 +0000', 'checkin_comment': 'Smells west coast, tastes savory hoppy. clear, light bodied but very tasty', 'rating_score': 4, 'user': {'uid': 1997677, 'user_name': 'Munchkinhc', 'first_name': 'Heather', 'last_name': 'C.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/fcdc2c3e061003e7beafe3aa783ea479_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3568228, 'beer_name': 'Squid Pro Quo "SPQ"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3568228_6faf9_sm.jpeg', 'beer_abv': 8, 'beer_ibu': 40, 'beer_slug': 'fab-fermentation-arts-fabcans-squid-pro-quo-spq', 'beer_description': 'fab.beer/spq; Chico fermented. West coast style.\r\n\r\nFermented with classic California ale yeast, SQP has a smoothly integrated citrus hop flavor happiness coming from a substantial bill of Citra and Simcoe hops added early in the mash and in multiple rounds of dry hopping. Naturally carbonated, Squid Pro Quo is capped after the last round of dry hopping to capture maximum hop aroma and create a fine, champagne-like carbonation', 'beer_style': 'IPA - American', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': [], 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871618058, 'comment_id': 55960958, 'comment_owner': False, 'comment_editor': False, 'comment': 'Great palate! Definitely invited to join our featured tasters... fab.beer/sticky ! (& Check out Citra squid, coming soon!) 🐙✋', 'created_at': 'Fri, 28 Feb 2020 04:08:25 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787594734, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:07:30 +0000'}]}, 'media': {'count': 0, 'items': []}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges': {'retro_status': False, 'count': 2, 'items': [{'badge_id': 6183, 'user_badge_id': 640206789, 'badge_name': 'Cheers To You! (Level 5)', 'badge_description': "Happy Untappd anniversary to you! Thanks for sticking around and drinking socially with us. Cheers! That's 5 years on Untappd!", 'created_at': 'Thu, 27 Feb 2020 23:36:22 +0000', 'badge_image': {'sm': 'https://untappd.akamaized.net/badges/bdg_HeresToYou_sm.jpg', 'md': 'https://untappd.akamaized.net/badges/bdg_HeresToYou_md.jpg', 'lg': 'https://untappd.akamaized.net/badges/bdg_HeresToYou_lg.jpg'}}, {'badge_id': 2599, 'user_badge_id': 640206790, 'badge_name': 'I Believe in IPA!  (Level 13)', 'badge_description': "We believe in IPA and you should too. You certainly have a taste for the hops! That's 65 d ...
# 871618058 2020-02-27 18:36:22-05:00 b'Squid Pro Quo "SPQ"' b''
# {'checkin_id': 871617563, 'created_at': 'Thu, 27 Feb 2020 23:35:20 +0000', 'checkin_comment': "Interesting flavors... Smells like a wear coast, tastes like a savory IPA. Nice mix, and unique. Don't love it, but I like the idea.", 'rating_score': 3.25, 'user': {'uid': 3572265, 'user_name': 'KMBaxter', 'first_name': 'Kyle', 'last_name': 'B.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': '', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/eb308021782be9c313e5466d3a78f358_100x100.jpeg', 'is_private': 0}, 'beer': {'bid': 3568228, 'beer_name': 'Squid Pro Quo "SPQ"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3568228_6faf9_sm.jpeg', 'beer_abv': 8, 'beer_ibu': 40, 'beer_slug': 'fab-fermentation-arts-fabcans-squid-pro-quo-spq', 'beer_description': 'fab.beer/spq; Chico fermented. West coast style.\r\n\r\nFermented with classic California ale yeast, SQP has a smoothly integrated citrus hop flavor happiness coming from a substantial bill of Citra and Simcoe hops added early in the mash and in multiple rounds of dry hopping. Naturally carbonated, Squid Pro Quo is capped after the last round of dry hopping to capture maximum hop aroma and create a fine, champagne-like carbonation', 'beer_style': 'IPA - American', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': [], 'comments': {'total_count': 0, 'count': 0, 'items': []}, 'toasts': {'total_count': 0, 'count': 0, 'auth_toast': False, 'items': []}, 'media': {'count': 0, 'items': []}, 'source': {'app_name': 'Untappd for iPhone - (V2)', 'app_website': 'http://untpd.it/iphoneapp'}, 'badges': {'retro_status': False, 'count': 2, 'items': [{'badge_id': 96, 'user_badge_id': 640206309, 'badge_name': 'New Brew Thursday (Level 3)', 'badge_description': "It's New Brew Thursday! Drink any beer you have never had before on three Thursdays in a 30 day period!", 'created_at': 'Thu, 27 Feb 2020 23:35:20 +0000', 'badge_image': {'sm': 'https://untappd.akamaized.net/badges/bdg_NewNewBrewThurs_sm.jpg', 'md': 'https://untappd.akamaized.net/badges/bdg_NewNewBrewThurs_md.jpg', 'lg': 'https://untappd.akamaized.net/badges/bdg_NewNewBrewThurs_lg.jpg'}}, {'badge_id': 133271, 'user_badge_id': 640206310, 'badge_name': 'Draft City (Level 18)', 'badge_description': "Fresh from the tap is one of the best ways to enjoy a beer. Just try to use a glass and not drink directly from the tap, as tempting as it may be. That's 90 checkins with the serving style of Draft. Try 5 more for Level 19!", 'created_at': 'Thu, 27 Feb 2020 23:35:20 +0000', 'badge_image': {'sm': 'https://untappd.akamaized.net/badges/bdg_DraftCity_sm.jpg', 'md': 'https://untappd.akamaized.net/badges/bdg_DraftCity_md.jpg', 'lg': 'https://untappd.akamaized.net/badges/bdg_DraftCity_lg.jpg'}}]}}
# ...
# 871382829 2020-02-26 20:28:31-05:00 b'Squid Pro Quo "SPQ"' b''
# {'checkin_id': 871382491, 'created_at': 'Thu, 27 Feb 2020 01:27:34 +0000', 'checkin_comment': 'Woooo weeeee. Pretty sweet stuff. Anti-trump labeling. Kick ass babyyyyyyyyyy!!!!!!!', 'rating_score': 4.5, 'user': {'uid': 1922290, 'user_name': 'becoolaboutit', 'first_name': 'Evan', 'last_name': 'F.', 'location': '', 'url': '', 'is_supporter': 0, 'bio': 'Sales Rep for Calmont Beverage.', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/2f840426ee8ec4a3dfc880b1fba2fd04_100x100.jpg', 'is_private': 0}, 'beer': {'bid': 3657888, 'beer_name': 'Tremendous  "TREM"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657888_9fecb_sm.jpeg', 'beer_abv': 9, 'beer_ibu': 60, 'beer_slug': 'fab-fermentation-arts-fabcans-tremendous-trem', 'beer_description': "fab.beer/trem; New England Double IPA (9%), brimming with passionfruit, citrus & pineapple flavors of Mosaic hops. Biotransformed by vigorous fermentation with our East Coast // New England IPA yeasts. TREMENDOUS, FAB's first 2xIPA explores many dimensions of hop additions. A blend of hops including juicy-tropical Mosaic, and grapefruit-citrusy Citra, are first added at 155F in the mash for early integration of flavorful trichomes and boosted in multiple rounds of whirlpool- and dry-hopping for aroma capture and flavor amplification. Adding hops during the height of fermentation and carefully controlling temperatures, we maximize hop aroma and gather natural CO2 in steel for flavorful, champagne-like effervescence, balanced flavor, and delicate sweetness.", 'beer_style': 'IPA - New England', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 1984113, 'venue_name': 'Elm Street Cemetery', 'venue_slug': 'elm-street-cemetery', 'primary_category_key': 'Outdoors & Recreation', 'primary_category': 'Outdoors & Recreation', 'parent_category_id': '4d4b7105d754a06377d81259', 'categories': {'count': 1, 'items': [{'category_key': 'cemetery', 'category_name': 'Cemetery', 'category_id': '4bf58dd8d48988d15c941735', 'is_primary': True}]}, 'location': {'venue_address': '666 Elm St', 'venue_city': 'Montpelier', 'venue_state': 'VT', 'venue_country': 'United States', 'lat': 44.2641, 'lng': -72.5716}, 'contact': {'twitter': '', 'venue_url': ''}, 'foursquare': {'foursquare_id': '4f3dd723e4b0d0c630fa741d', 'foursquare_url': 'http://4sq.com/AwbSVJ'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/cemetery_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/cemetery_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/cemetery_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871382491, 'comment_id': 55960921, 'comment_owner': False, 'comment_editor': False, 'comment': '🐙🐙🛸', 'created_at': 'Fri, 28 Feb 2020 04:05:40 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 2, 'count': 2, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship':  ...
# 871382491 2020-02-26 20:27:34-05:00 b'Tremendous  "TREM"' b'Elm Street Cemetery'
# {'checkin_id': 871363766, 'created_at': 'Thu, 27 Feb 2020 00:39:34 +0000', 'checkin_comment': '', 'rating_score': 4.25, 'user': {'uid': 725788, 'user_name': '1ofakynd', 'first_name': 'MATTHEW', 'last_name': 'M.', 'location': 'Rye, NH', 'url': '', 'is_supporter': 0, 'bio': 'Beer traveler, pint glass collector and lover of all things U of Michigan.  Go Blue!  Not a fan of IPAs or imperials.', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/51dc44ca6e74f3aa4118db2205a29591_thumb.jpg', 'is_private': 0}, 'beer': {'bid': 3657979, 'beer_name': 'Pilsner 4 Peace "P4P"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3657979_4270c_sm.jpeg', 'beer_abv': 5, 'beer_ibu': 35, 'beer_slug': 'fab-fermentation-arts-fabcans-pilsner-4-peace-p4p', 'beer_description': 'fab.beer/p4p; American-style Pilsner, with subtle layers of Mandarina Bavaria and Citra hops, created in partnership between brewers and international, activist artists. In-keeping with the American Pilsner style, P4P\'s assertive hoppiness is infused in multiple stages of mash- and biotransformational, "High Krausen" dry-hopping. Clean and easy-drinking, with some sweetness and counter-balancing bitterness, the PILSNER 4 PEACE is envisioned as an international open-source collaboration beer. Participating breweries are invited to collaborate on this open recipe, and all they have to do is pay local artists a fair price to contribute to our global art series. For more information, check out fab.beer/p4p ...', 'beer_style': 'Pilsner - Other', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 3264221, 'venue_name': "M&M 's  Ocean  Dream", 'venue_slug': 'm-m-s-ocean-dream', 'primary_category_key': 'Residence', 'primary_category': 'Residence', 'parent_category_id': '4e67e38e036454776db1fb3a', 'categories': {'count': 1, 'items': [{'category_key': 'home_private', 'category_name': 'Home (private)', 'category_id': '4bf58dd8d48988d103941735', 'is_primary': True}]}, 'location': {'venue_address': '', 'venue_city': 'Rye', 'venue_state': 'NH', 'venue_country': 'United States', 'lat': 43.0111, 'lng': -70.7466}, 'contact': {'twitter': '', 'venue_url': ''}, 'foursquare': {'foursquare_id': '55ab0586498e17c485703a6f', 'foursquare_url': 'http://4sq.com/1VfTCkT'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/building/home_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/building/home_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/building/home_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871363766, 'comment_id': 55960914, 'comment_owner': False, 'comment_editor': False, 'comment': 'P4P art series 2 coming soon! 🌍', 'created_at': 'Fri, 28 Feb 2020 04:05:18 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 1, 'count': 1, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos ...
# 871363766 2020-02-26 19:39:34-05:00 b'Pilsner 4 Peace "P4P"' b"M&M 's  Ocean  Dream"
# {'checkin_id': 871329060, 'created_at': 'Wed, 26 Feb 2020 23:07:13 +0000', 'checkin_comment': 'Dang, love the label', 'rating_score': 4, 'user': {'uid': 184956, 'user_name': 'Chedda', 'first_name': 'Kyle', 'last_name': 'T.', 'location': 'Watertown, MA', 'url': '', 'is_supporter': 0, 'bio': 'Bieratheist', 'relationship': None, 'user_avatar': 'https://untappd.akamaized.net/profile/c2f41eab5279f8bdee52fedb9326c51e_100x100.jpeg', 'is_private': 0}, 'beer': {'bid': 3568228, 'beer_name': 'Squid Pro Quo "SPQ"', 'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3568228_6faf9_sm.jpeg', 'beer_abv': 8, 'beer_ibu': 40, 'beer_slug': 'fab-fermentation-arts-fabcans-squid-pro-quo-spq', 'beer_description': 'fab.beer/spq; Chico fermented. West coast style.\r\n\r\nFermented with classic California ale yeast, SQP has a smoothly integrated citrus hop flavor happiness coming from a substantial bill of Citra and Simcoe hops added early in the mash and in multiple rounds of dry hopping. Naturally carbonated, Squid Pro Quo is capped after the last round of dry hopping to capture maximum hop aroma and create a fine, champagne-like carbonation', 'beer_style': 'IPA - American', 'has_had': False, 'beer_active': 1}, 'brewery': {'brewery_id': 451812, 'brewery_name': 'FAB Fermentation Arts ... fabcans', 'brewery_slug': 'fab-fermentation-arts-fabcans', 'brewery_page_url': '/fabcans', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'country_name': 'United States', 'contact': {'twitter': 'fabcans', 'facebook': 'http://facebook.com/fabcans', 'url': 'http://fab.beer/sticky'}, 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}, 'brewery_active': 1}, 'venue': {'venue_id': 5675250, 'venue_name': 'Trident Galley & Raw Bar', 'venue_slug': 'trident-galley-raw-bar', 'primary_category_key': 'Food', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'seafood_restaurant', 'category_name': 'Seafood Restaurant', 'category_id': '4bf58dd8d48988d1ce941735', 'is_primary': True}]}, 'location': {'venue_address': '23 Shipyard Dr', 'venue_city': 'Hingham', 'venue_state': 'MA', 'venue_country': 'United States', 'lat': 42.2519, 'lng': -70.9216}, 'contact': {'twitter': '', 'venue_url': 'https://www.tridentrawbar.com'}, 'foursquare': {'foursquare_id': '583a2869dfa6ff689c64cfe7', 'foursquare_url': 'http://4sq.com/2g4tM6B'}, 'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_bg_64.png', 'md': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_bg_88.png', 'lg': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_bg_512.png'}, 'is_verified': False}, 'comments': {'total_count': 1, 'count': 1, 'items': [{'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'is_supporter': 0, 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'checkin_id': 871329060, 'comment_id': 55960895, 'comment_owner': False, 'comment_editor': False, 'comment': 'Citra squid landing soon! 🍊🐙 fab.beer/sticky !', 'created_at': 'Fri, 28 Feb 2020 04:04:13 +0000', 'comment_source': 'API'}]}, 'toasts': {'total_count': 2, 'count': 2, 'auth_toast': None, 'items': [{'uid': 7413189, 'user': {'uid': 7413189, 'user_name': 'fabcans', 'first_name': 'FAB', 'last_name': '', 'bio': '', 'location': '', 'relationship': 'none', 'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-451812_b55d5.jpeg', 'account_type': 'brewery', 'venue_details': [], 'brewery_details': {'brewery_id': 451812}, 'user_link': 'https://untappd.com/brewery/451812'}, 'like_id': 787593803, 'like_owner': False, 'created_at': 'Fri, 28 Feb 2020 04:03:47 +0000'}, {'uid': 6874106, 'user': {'uid': 687410 ...
# 871329060 2020-02-26 18:07:13-05:00 b'Squid Pro Quo "SPQ"' b'Trident Galley & Raw Bar'
# {'client_id': 'E8847D1FA347C37248DEC90E1D21568E18FC5152', 'client_secret': '199C86117D183A9B6BCB3220098F34CFF81FD562', 'limit': 100, 'min_id': 871703610}
# {'count': 0, 'items': []}

# %%
google_sheet_url_1 = "https://docs.google.com/spreadsheets/d/1cozZyyhcIRuwhdi5Z056_-8LoHC_YR_k-498HTS0-u8/export?format=csv#gid=400302575"
partners_report =pd.read_csv(google_sheet_url_1,skiprows=0)

# %%
google_sheet_url_2 = "https://docs.google.com/spreadsheets/d/1cozZyyhcIRuwhdi5Z056_-8LoHC_YR_k-498HTS0-u8/export?format=csv&id=1cozZyyhcIRuwhdi5Z056_-8LoHC_YR_k-498HTS0-u8&gid=1966703241"
sales_report=pd.read_csv(google_sheet_url_2,skiprows=0)

# %%
#accesses can database on airtable
#writes to cans.csv

from airtable import Airtable
base_key = 'appR312nFpbS1UbOH'
table_name = 'FAB Cans'
airtable = Airtable(base_key, table_name, api_key="key78z9GoFTdaPlYd")
record_list = airtable.get_all()
cans_df = pd.DataFrame([record['fields'] for record in record_list]).loc[lambda x: ~x.code.isna()]
cans_df.to_csv("../_data/cans.csv")
for i, r in cans_df.iterrows():
    s = yaml.dump(r.to_dict(), default_flow_style=False)
    with open(f"../_cans/{r.code}.md","w") as f:
        f.write("---\n"),
        f.write(s)
        f.write("\n---\n")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in _process_response(self, response)
#     141         try:
# --> 142             response.raise_for_status()
#     143         except requests.exceptions.HTTPError as exc:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://api.airtable.com/v0/appR312nFpbS1UbOH/Cans
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-b40f281b2d46> in <module>
#       6 table_name = 'Cans'
#       7 airtable = Airtable(base_key, table_name, api_key="key78z9GoFTdaPlYd")
# ----> 8 record_list = airtable.get_all()
#       9 cans_df = pd.DataFrame([record['fields'] for record in record_list]).loc[lambda x: ~x.code.isna()]
#      10 cans_df.to_csv("../_data/cans.csv")
#
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in get_all(self, **options)
#     271         """
#     272         all_records = []
# --> 273         for records in self.get_iter(**options):
#     274             all_records.extend(records)
#     275         return all_records
#
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in get_iter(self, **options)
#     235         offset = None
#     236         while True:
# --> 237             data = self._get(self.url_table, offset=offset, **options)
#     238             records = data.get("records", [])
#     239             time.sleep(self.API_LIMIT)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in _get(self, url, **params)
#     173     def _get(self, url, **params):
#     174         processed_params = self._process_params(params)
# --> 175         return self._request("get", url, params=processed_params)
#     176
#     177     def _post(self, url, json_data):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in _request(self, method, url, params, json_data)
#     169     def _request(self, method, url, params=None, json_data=None):
#     170         response = self.session.request(method, url, params=params, json=json_data)
# --> 171         return self._process_response(response)
#     172
#     173     def _get(self, url, **params):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/airtable/airtable.py in _process_response(self, response)
#     159                 if "error" in error_dict:
#     160                     err_msg += " [Error: {}]".format(error_dict["error"])
# --> 161             raise requests.exceptions.HTTPError(err_msg)
#     162         else:
#     163             return response.json()
#
# HTTPError: 404 Client Error: Not Found for url: https://api.airtable.com/v0/appR312nFpbS1UbOH/Cans [Error: {'type': 'TABLE_NOT_FOUND', 'message': 'Could not find table Cans in application appR312nFpbS1UbOH'}]

# %%
cans_df.balloon_string_len

# %%
# accesses off premises partners from google sheets
# writes to offprem.csv

google_sheet_url_3 = "https://docs.google.com/spreadsheets/d/1cozZyyhcIRuwhdi5Z056_-8LoHC_YR_k-498HTS0-u8/export?format=csv&id=1cozZyyhcIRuwhdi5Z056_-8LoHC_YR_k-498HTS0-u8&gid=45430792"
map_partners = pd.read_csv(google_sheet_url_3, skiprows = 0)
map_partners.to_csv("../_data/offprem_can_locations.csv")
