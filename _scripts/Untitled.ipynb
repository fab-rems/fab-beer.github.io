# %%
import pandas as pd
import subprocess as spc
import io

# %%
result = pd.read_json("https://craftcollectivedist.com/ECP_20.01_A/aspx1/API.ashx?APICommand=FusionView&ReportID=5126386&Format=json")

# %%
import json

# %%
cmd = """curl 'https://craftcollectivedist.com/ECP_20.01_A/aspx1/API.ashx?APICommand=FusionView&ReportID=5126386&Format=json' -H 'authority: craftcollectivedist.com' -H 'cache-control: max-age=0' -H 'upgrade-insecure-requests: 1' -H 'user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36' -H 'sec-fetch-user: ?1' -H 'accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9' -H 'sec-fetch-site: none' -H 'sec-fetch-mode: navigate' -H 'accept-encoding: gzip, deflate, br' -H 'accept-language: en-US,en;q=0.9' -H 'cookie: Email=ben@fab.beer; EncompassDistributor=CraftCollect; EncompassDBServer=MySQL12; EncompassSessionID=95df7789004cc2001dfad2e7b1e48958; MenuCollapsed=False; EncompassGuestDashboardID=147731; ExpireTime=1580063124723' --compressed"""
res = spc.Popen(cmd, shell=True, stdout =spc.PIPE)
jdata = res.communicate()[0]
jsonio = io.BytesIO(jdata)
df = pd.DataFrame(json.loads(jdata)['Export']['Report']['Row'])

# %%
df
# Out:
#          Location                     Company CustomerType  \
# 0           Maine            Tomaso's Canteen   On Premise
# 1           Maine                 711 Kittery  Off Premise
# 2           Maine                 711 Kittery  Off Premise
# 3           Maine                 Bier Cellar  Off Premise
# 4           Maine                 Bier Cellar  Off Premise
# ..            ...                         ...          ...
# 439  Rhode Island              Putnam Liquors  Off Premise
# 440  Rhode Island              Putnam Liquors  Off Premise
# 441  Rhode Island   The Abbey (ForePlay Inc.)   On Premise
# 442  Rhode Island  The Savory Grape (bottles)  Off Premise
# 443  Rhode Island  The Savory Grape (bottles)  Off Premise
#
#                    ShippingAddress            City State PostalCode  \
# 0        93 Washington Ave Unit #1  South Portland    ME      04401
# 1                   169 State Road         Kittery    ME      03904
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-f2f4dfb3730e> in <module>
#       1 jdata = res.communicate()[0]
# ----> 2 out = pd.read_csv(jdata)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...
